# %%
# !pip install selenium
# !pip install webdriver-manager
# Out:
# ...
#   Using cached webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# ...
# Using cached webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Chrome()

driver.get("https://www.google.com")

search = driver.find_element(By.NAME, "q")
search.send_keys("Selenium in Jupyter")
search.send_keys(Keys.RETURN)

time.sleep(3)

print("Title:", driver.title)

driver.quit()
# Out:
# Title: https://www.google.com/search?q=Selenium+in+Jupyter&sca_esv=206cd4dd954885db&source=hp&ei=CbqeaYLjOquU4-EPu9aRsAk&iflsig=AFdpzrgAAAAAaZ7IGTh6L61ULNYqN-648L6znDb6jsyg&ved=0ahUKEwjCi-rRo_SSAxUryjgGHTtrBJYQ4dUDCBY&uact=5&oq=Selenium+in+Jupyter&gs_lp=Egdnd3Mtd2l6IhNTZWxlbml1bSBpbiBKdXB5dGVySKEDUABYgwFwAHgAkAEAmAEAoAEAqgEAuAEDyAEA-AEBmAIAoAIAmAMAkgcAoAcAsgcAuAcAwgcAyAcAgAgA&sclient=gws-wiz&sei=DLqeaeOaKuOVjuMPr_iH4AY

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
driver.get('https://www.w3schools.com/python/python_output.asp')
title = driver.find_elements(By.CLASS_NAME,"pythoncolor")
for t in title:
    print(t.text)
driver.quit()
# Out:
# print("Hello World!")
# print("Hello World!")
# print("I am learning Python.")
# print("It is awesome!")
# print("This will work!")
# print('This will also work!')
# print(This will cause an error)
# print("Hello World!", end=" ")
# print("I will print on the same line.")

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
driver.get('https://www.w3schools.com/python/python_output.asp')
button = driver.find_elements(By.CLASS_NAME,"w3-btn")
button[0].click()
for t in button:
    print(t.text)
button[0].click()
driver.quit()
# Out:
# Sign In
# ❮ Previous
# Next ❯
# Try it Yourself »
# Try it Yourself »
# Try it Yourself »
# Try it Yourself »
# Try it Yourself »
# ❮ Previous
# Next ❯

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
driver.get('https://www.w3schools.com/python/trypython.asp?filename=demo_variables_casting')
title = driver.find_elements(By.ID,"iframeResult")
for t in title:
    print(t.text)
driver.quit()
# Out:
# 3
# 3
# 3.0
