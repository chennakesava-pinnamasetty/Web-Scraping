# %%
# !pip install curl_cffi
# Out:
# Requirement already satisfied: curl_cffi in c:\users\chenn\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\chenn\anaconda3\lib\site-packages (from curl_cffi) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\chenn\anaconda3\lib\site-packages (from curl_cffi) (2025.4.26)
# Requirement already satisfied: pycparser in c:\users\chenn\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi) (2.21)

# %%
import curl_cffi
print("Installed successfully!")
# Out:
# Installed successfully!

# %%
from curl_cffi import requests
from bs4 import BeautifulSoup

url = "https://books.toscrape.com/"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36 Edg/145.0.0.0"
}

response = requests.get(url, headers=headers, impersonate="chrome")

soup = BeautifulSoup(response.text, "html.parser")

books = soup.find_all("article", class_="product_pod")

print(response.status_code)
#print(response.text)

for book in books[:5]:
    title = book.h3.a["title"]
    price = book.find("p", class_="price_color")

    print("Title:", title) 
    print("Price:", price) 
    print("----------------------")
# Out:
# 200
# Title: A Light in the Attic
# Price: <p class="price_color">£51.77</p>
# ----------------------
# Title: Tipping the Velvet
# Price: <p class="price_color">£53.74</p>
# ----------------------
# Title: Soumission
# Price: <p class="price_color">£50.10</p>
# ----------------------
# Title: Sharp Objects
# Price: <p class="price_color">£47.82</p>
# ----------------------
# Title: Sapiens: A Brief History of Humankind
# Price: <p class="price_color">£54.23</p>
# ----------------------
